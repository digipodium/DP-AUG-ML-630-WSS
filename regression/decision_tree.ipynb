# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.model_selection import train_test_split, cross_validate, ShuffleSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
url = 'https://raw.githubusercontent.com/digipodium/Datasets/main/regression/diamond_pricing.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Paleonium  Pressure        Price
# 0         17      6567  2810.280298
# 1         59      5253  1986.967089
# 2        123      9715  2083.132087
# 3        182      2073  2236.340285
# 4        133      6400  1903.323339

# %%
df.plot(kind='scatter',
    x='Paleonium',y='Pressure',c='Price',cmap='viridis',figsize=(10,6))
plt.show()

# %%
df.corrwith(df['Price']).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### simple impln

# %%
X = df.drop('Price',axis=1).values
y = df['Price'].values

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=.25, random_state=0)

# %%
model = make_pipeline(StandardScaler(),DecisionTreeRegressor())

# %%
model.fit(xtrain, ytrain)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeregressor', DecisionTreeRegressor())])

# %%
print("Testing Metrics")
ypred = model.predict(xtest)
print(f'score : {r2_score(ytest, ypred):.4}')
print(f'mse : {mean_squared_error(ytest, ypred):.4}')
print(f'mae : {mean_absolute_error(ytest, ypred):.4}')
# Out:
# Testing Metrics
# score : 0.96
# mse : 1.696e+04
# mae : 99.49

# %%
print("Training Metrics")
ypred = model.predict(xtrain)
print(f'score : {r2_score(ytrain, ypred):.4}')
print(f'mse : {mean_squared_error(ytrain, ypred):.4}')
print(f'mae : {mean_absolute_error(ytrain, ypred):.4}')
# Out:
# Training Metrics
# score : 1.0
# mse : 0.0
# mae : 0.0

# %%
plt.figure(figsize=(25,25))
plot_tree(model.get_params()['decisiontreeregressor'], 
            max_depth=5,
            feature_names=['Paleonium','Pressure'],
            fontsize=8, proportion=True, rounded=True)
plt.show()

# %% [markdown]
# ### cross validate

# %%
ss = ShuffleSplit(n_splits=50, test_size=.25)
model = make_pipeline(StandardScaler(),DecisionTreeRegressor(max_depth=15))

# %%
result = cross_validate(model, X, y, cv=ss, 
                        scoring=['neg_mean_absolute_error','r2'],
                        return_train_score=True,
                        return_estimator=True)
result = pd.DataFrame(result)
result['test_error'] = -result['test_neg_mean_absolute_error']
result['train_error'] = -result['train_neg_mean_absolute_error']
result
# Out:
#     fit_time  score_time                                          estimator  \
# 0   0.002001    0.001001  (StandardScaler(), DecisionTreeRegressor(max_d...
# 1   0.001000    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 2   0.000999    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 3   0.002001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 4   0.002000    0.001001  (StandardScaler(), DecisionTreeRegressor(max_d...
# 5   0.002000    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 6   0.002000    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 7   0.002002    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 8   0.002000    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 9   0.002001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 10  0.003001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 11  0.002001    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 12  0.001001    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 13  0.001001    0.001002  (StandardScaler(), DecisionTreeRegressor(max_d...
# 14  0.001000    0.000999  (StandardScaler(), DecisionTreeRegressor(max_d...
# 15  0.002001    0.001001  (StandardScaler(), DecisionTreeRegressor(max_d...
# 16  0.002000    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 17  0.002000    0.001001  (StandardScaler(), DecisionTreeRegressor(max_d...
# 18  0.000999    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 19  0.001001    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 20  0.001000    0.001001  (StandardScaler(), DecisionTreeRegressor(max_d...
# 21  0.001001    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 22  0.002001    0.000998  (StandardScaler(), DecisionTreeRegressor(max_d...
# 23  0.001000    0.000998  (StandardScaler(), DecisionTreeRegressor(max_d...
# 24  0.002000    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 25  0.001000    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 26  0.002002    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 27  0.002000    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 28  0.002001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 29  0.002000    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 30  0.002002    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 31  0.001999    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 32  0.001000    0.001001  (StandardScaler(), DecisionTreeRegressor(max_d...
# 33  0.001000    0.000999  (StandardScaler(), DecisionTreeRegressor(max_d...
# 34  0.001000    0.001002  (StandardScaler(), DecisionTreeRegressor(max_d...
# 35  0.002000    0.000999  (StandardScaler(), DecisionTreeRegressor(max_d...
# 36  0.002001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 37  0.002000    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 38  0.002001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 39  0.002001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 40  0.002000    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 41  0.001001    0.000999  (StandardScaler(), DecisionTreeRegressor(max_d...
# 42  0.001000    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 43  0.001000    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 44  0.002000    0.001000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 45  0.002001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 46  0.002000    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 47  0.002001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 48  0.002001    0.000000  (StandardScaler(), DecisionTreeRegressor(max_d...
# 49  0.001001    0.001003  (StandardScaler(), DecisionTreeRegressor(max_d...
#
#     test_neg_mean_absolute_error  train_neg_mean_absolute_error   test_r2  \
# 0                     -93.798221                      -9.179346  0.961311
# 1                     -94.321946                      -7.017847  0.968604
# 2                     -95.538710                      -5.806805  0.967053
# 3                     -98.400197                      -5.046377  0.948957
# 4                     -98.476413                      -4.995870  0.952641
# 5                     -99.141810                      -6.987076  0.965779
# 6                     -96.909487                      -5.337355  0.964196
# 7                     -90.420851                      -7.772667  0.953733
# 8                    -102.441813                      -4.819431  0.945477
# 9                     -89.906426                      -5.002883  0.966999
# 10                   -101.533496                      -6.132397  0.958289
# 11                   -105.397452                      -7.959518  0.954913
# 12                    -97.544377                      -7.297864  0.964116
# 13                    -98.740673                      -5.256057  0.969455
# 14                    -96.532644                      -5.318677  0.955174
# 15                    -91.353451                      -8.601683  0.965612
# 16                    -95.711493                      -7.113560  0.971531
# 17                   -103.445266                      -6.589139  0.960408
# 18                    -93.914075                      -6.752242  0.961565
# 19                    -93.415291                      -5.142887  0.963882
# 20                    -98.408589                      -6.791251  0.962809
# 21                   -105.973598                      -5.931770  0.959720
# 22                    -89.757194                      -5.431007  0.966489
# 23                    -97.463991                      -3.882320  0.964844
# 24                    -83.167723                      -5.128061  0.967540
# 25                    -98.206748                      -5.727576  0.961673
# 26                    -97.273700                      -5.851183  0.959784
# 27                    -87.247326                      -5.657823  0.973799
# 28                   -120.484357                      -6.205841  0.946447
# 29                   -102.807709                      -4.753223  0.959560
# 30                    -87.715096                      -5.058254  0.968056
# 31                   -104.313532                      -6.273354  0.958188
# 32                    -98.197348                      -6.694619  0.960358
# 33                    -94.850171                      -6.892815  0.963709
# 34                    -93.871745                      -4.920962  0.966770
# 35                   -103.377175                      -5.589426  0.952458
# 36                    -95.339347                      -6.293900  0.968551
# 37                    -96.636900                      -5.656712  0.958879
# 38                    -98.253323                      -4.670356  0.955927
# 39                   -105.766113                      -5.937526  0.937958
# 40                    -99.852242                      -5.770969  0.966364
# 41                    -90.071618                      -5.687619  0.966547
# 42                    -83.808436                      -5.256741  0.967421
# 43                    -98.711333                      -7.192061  0.963059
# 44                    -98.156880                      -4.283099  0.962622
# 45                    -98.323829                      -7.535958  0.962433
# 46                    -94.710793                      -6.517697  0.960536
# 47                   -102.396296                      -6.536236  0.960811
# 48                    -93.828628                      -5.504015  0.966580
# 49                   -104.475897                      -4.904613  0.959591
#
#     train_r2  test_error  train_error
# 0   0.998822   93.798221     9.179346
# 1   0.999013   94.321946     7.017847
# 2   0.999321   95.538710     5.806805
# 3   0.999523   98.400197     5.046377
# 4   0.999508   98.476413     4.995870
# 5   0.999168   99.141810     6.987076
# 6   0.999410   96.909487     5.337355
# 7   0.999054   90.420851     7.772667
# 8   0.999457  102.441813     4.819431
# 9   0.999448   89.906426     5.002883
# 10  0.999282  101.533496     6.132397
# 11  0.999015  105.397452     7.959518
# 12  0.999111   97.544377     7.297864
# 13  0.999369   98.740673     5.256057
# 14  0.999411   96.532644     5.318677
# 15  0.998933   91.353451     8.601683
# 16  0.999060   95.711493     7.113560
# 17  0.999156  103.445266     6.589139
# 18  0.999267   93.914075     6.752242
# 19  0.999439   93.415291     5.142887
# 20  0.999189   98.408589     6.791251
# 21  0.999225  105.973598     5.931770
# 22  0.999339   89.757194     5.431007
# 23  0.999624   97.463991     3.882320
# 24  0.999446   83.167723     5.128061
# 25  0.999266   98.206748     5.727576
# 26  0.999256   97.273700     5.851183
# 27  0.999299   87.247326     5.657823
# 28  0.999166  120.484357     6.205841
# 29  0.999460  102.807709     4.753223
# 30  0.999456   87.715096     5.058254
# 31  0.999294  104.313532     6.273354
# 32  0.999152   98.197348     6.694619
# 33  0.999240   94.850171     6.892815
# 34  0.999465   93.871745     4.920962
# 35  0.999377  103.377175     5.589426
# 36  0.999166   95.339347     6.293900
# 37  0.999350   96.636900     5.656712
# 38  0.999515   98.253323     4.670356
# 39  0.999339  105.766113     5.937526
# 40  0.999332   99.852242     5.770969
# 41  0.999312   90.071618     5.687619
# 42  0.999372   83.808436     5.256741
# 43  0.999092   98.711333     7.192061
# 44  0.999464   98.156880     4.283099
# 45  0.998962   98.323829     7.535958
# 46  0.999308   94.710793     6.517697
# 47  0.999240  102.396296     6.536236
# 48  0.999326   93.828628     5.504015
# 49  0.999363  104.475897     4.904613

# %%
fig, ax = plt.subplots(figsize=(10,5))
result[['train_error','test_error']].plot(kind='hist',bins=50,ax=ax,edgecolor='black')
plt.show()

# %%
from sklearn.model_selection import validation_curve

# %%
max_depth_options = [5,10,15,25,50,100]
train_scores, test_scores = validation_curve(model,X,y,
                            param_name='decisiontreeregressor__max_depth',
                            param_range=max_depth_options,
                            cv=ss,
                            scoring='neg_mean_absolute_error',
                            n_jobs=2)
train_errors, test_errors = -train_scores, -test_scores

# %%
plt.plot(train_errors.mean(axis=1),'--x', label='training error',)
plt.plot(test_errors.mean(axis=1),'--x', label='testing error')
plt.xticks([0,1,2,3,4,5],max_depth_options)
plt.legend()
plt.show()
